# %% [markdown]
# # Inputs

# %%
# %reset -f

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.optim import AdamW

from transformers import RobertaTokenizer

from controller import Controller

# %%
LOAD_TENSORS = True
c = Controller('i02')
device = device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # Load data

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# %%
filepath = fr'{c.get_path_data_prepared()}/01_df_train_val_test.pkl'
df_train_val_test = pd.read_pickle(filepath)

df_train = df_train_val_test.query('TRAIN_VAL_TEST_SPLIT == "Train"')
print(f'{df_train.shape=}')
df_val = df_train_val_test.query('TRAIN_VAL_TEST_SPLIT == "Validation"')
print(f'{df_val.shape=}')
df_test = df_train_val_test.query('TRAIN_VAL_TEST_SPLIT == "Test"')
print(f'{df_test.shape=}')

df_train
# Out:
# df_train.shape=(38655, 114)
# df_val.shape=(4295, 114)
# df_test.shape=(4773, 114)
#        ACN_NUM_ACN  TIME_DATE TIME_1_LOCAL_TIME_OF_DAY PLACE_LOCALE_REFERENCE  \
# 0          1574675     201808                0601-1200            SNA.Airport
# 1          1224894     201412                0601-1200            MSY.Airport
# 2          1134202     201312                1201-1800              ZZZ.ARTCC
# 3          1222074     201411                1201-1800            CWA.Airport
# 4          1733019     202003                1801-2400              ZDV.ARTCC
# ...            ...        ...                      ...                    ...
# 38650      1093770     201306                       NA            MRY.Airport
# 38651      1580993     201809                1201-1800            DTW.Airport
# 38652      1438881     201704                       NA            ZZZ.Airport
# 38653      1614309     201901                0601-1200              ZZZ.ARTCC
# 38654      1163382     201404                1201-1800            ZZZ.Airport
#
#       PLACE_1_STATE_REFERENCE  PLACE_2_RELATIVE_POSITION_ANGLE_RADIAL  \
# 0                          CA                                     NaN
# 1                          LA                                     NaN
# 2                          US                                     NaN
# 3                          WI                                     NaN
# 4                          CO                                     NaN
# ...                       ...                                     ...
# 38650                      CA                                   330.0
# 38651                      MI                                     NaN
# 38652                      US                                     NaN
# 38653                      US                                     NaN
# 38654                      US                                     NaN
#
#        PLACE_3_RELATIVE_POSITION_DISTANCE_NAUTICAL_MILES  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   20.0
# 4                                                    NaN
# ...                                                  ...
# 38650                                                3.0
# 38651                                                NaN
# 38652                                                NaN
# 38653                                                NaN
# 38654                                                NaN
#
#        PLACE_4_ALTITUDE_AGL_SINGLE_VALUE  PLACE_5_ALTITUDE_MSL_SINGLE_VALUE  \
# 0                                    NaN                             5000.0
# 1                                 1000.0                                NaN
# 2                                    NaN                             2600.0
# 3                                    NaN                             4000.0
# 4                                    NaN                            32000.0
# ...                                  ...                                ...
# 38650                                NaN                             2500.0
# 38651                              250.0                                NaN
# 38652                                0.0                                NaN
# 38653                                NaN                            45000.0
# 38654                                0.0                                NaN
#
#       ENVIRONMENT_FLIGHT_CONDITIONS  ...  \
# 0                                NA  ...
# 1                               VMC  ...
# 2                               IMC  ...
# 3                                NA  ...
# 4                                NA  ...
# ...                             ...  ...
# 38650                           IMC  ...
# 38651                            NA  ...
# 38652                            NA  ...
# 38653                           VMC  ...
# 38654                           VMC  ...
#
#              ASSESSMENTS_CONTRIBUTING_FACTORS_SITUATIONS  \
# 0                                          Human Factors
# 1                                          Human Factors
# 2            Human Factors; Aircraft; Procedure; Weather
# 3                                               Aircraft
# 4                            Airspace Structure; Weather
# ...                                                  ...
# 38650                            Human Factors; Aircraft
# 38651       Environment - Non Weather Related; Procedure
# 38652                      Company Policy; Human Factors
# 38653                            Aircraft; Human Factors
# 38654  Aircraft; Environment - Non Weather Related; P...
#
#            ASSESSMENTS_1_PRIMARY_PROBLEM  \
# 0                          Human Factors
# 1                          Human Factors
# 2                               Aircraft
# 3                               Aircraft
# 4                                Weather
# ...                                  ...
# 38650                          Ambiguous
# 38651                          Procedure
# 38652                     Company Policy
# 38653                           Aircraft
# 38654  Environment - Non Weather Related
#
#                                       REPORT_1_NARRATIVE REPORT_1_1_CALLBACK  \
# 0      SNA RNP-Z to Runway 20R. The FMC was properly ...                  NA
# 1      On base to final turn to runway 1 in MSY at ap...                  NA
# 2      I climbed to my filed altitude of 5;000 FT; an...                  NA
# 3      I had my pitot heat checked prior to winter an...                  NA
# 4      At 32000 ft. just north of PUB the aircraft ex...                  NA
# ...                                                  ...                 ...
# 38650  Maintain directional control during climbout t...                  NA
# 38651  Given takeoff clearance from 21R in DTW behind...                  NA
# 38652  I did not witness passenger boarding as I was ...                  NA
# 38653  Extreme cold cockpit temperatures were experie...                  NA
# 38654  I was the pilot flying performing the takeoff....                  NA
#
#                                       REPORT_2_NARRATIVE REPORT_2_1_CALLBACK  \
# 0      We were cleared for the RNP RNAV Z 20R Approac...                  NA
# 1                                                     NA                  NA
# 2                                                     NA                  NA
# 3                                                     NA                  NA
# 4                                                     NA                  NA
# ...                                                  ...                 ...
# 38650                                                 NA                  NA
# 38651                                                 NA                  NA
# 38652                                                 NA                  NA
# 38653  [Report narrative contained no additional info...                  NA
# 38654  At approximately 75 KTS I glanced at my airspe...                  NA
#
#                                      REPORT_1_2_SYNOPSIS TRAIN_VAL_TEST_SPLIT  \
# 0      B737-700 flight crew reported failing to make ...                Train
# 1      Captain reports sighting of a drone at 1;000 f...                Train
# 2      SR22 pilot became disoriented on approach in I...                Train
# 3      BE58 pilot experiences pitot heat failure desc...                Train
# 4      B737 First Officer reported unexpected moderat...                Train
# ...                                                  ...                  ...
# 38650  C172 instructor pilot reports difficulties wit...                Train
# 38651  CRJ-900 Captain reported encountering wake tur...                Train
# 38652  Boeing 787 Flight Attendant reported an adult ...                Train
# 38653  EMB-505 flight crew reported the loss of tempe...                Train
# 38654  A B767 Captain; the pilot not flying; rejected...                Train
#
#       EVENT_RISK        EVENT_RISK_STR
# 0              2           Medium risk
# 1              0              Low risk
# 2              3  Moderately high risk
# 3              2           Medium risk
# 4              3  Moderately high risk
# ...          ...                   ...
# 38650          2           Medium risk
# 38651          2           Medium risk
# 38652          0              Low risk
# 38653          2           Medium risk
# 38654          2           Medium risk
#
# [38655 rows x 114 columns]

# %% [markdown]
# # Prepare data

# %%
features = ['REPORT_1_NARRATIVE', 'REPORT_1_1_CALLBACK', 'REPORT_2_NARRATIVE', 'REPORT_2_1_CALLBACK', 'REPORT_1_2_SYNOPSIS']

# %% [markdown]
# ## Check missing values

# %%
for feature in features:
    missing = df_train.query(f'{feature} == "NA"').shape[0]
    total = df_train.shape[0]
    print(f'{feature}, {missing=}, {total=} => {missing / total:.2%}')
# Out:
# REPORT_1_NARRATIVE, missing=0, total=38655 => 0.00%
# REPORT_1_1_CALLBACK, missing=37474, total=38655 => 96.94%
# REPORT_2_NARRATIVE, missing=29544, total=38655 => 76.43%
# REPORT_2_1_CALLBACK, missing=38592, total=38655 => 99.84%
# REPORT_1_2_SYNOPSIS, missing=0, total=38655 => 0.00%

# %% [markdown]
# ## Get max length for narratives

# %%
for feature in features:
    lens = df_train[feature].map(len)
    print(f'{feature} => max={np.max(lens)} avg={np.mean(lens):.2f}')
# Out:
# REPORT_1_NARRATIVE => max=11991 avg=1586.71
# REPORT_1_1_CALLBACK => max=3959 avg=20.95
# REPORT_2_NARRATIVE => max=11955 avg=228.82
# REPORT_2_1_CALLBACK => max=2749 avg=3.04
# REPORT_1_2_SYNOPSIS => max=959 avg=171.53

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    X = df['REPORT_1_NARRATIVE']
    y = df['EVENT_RISK']
    
    X = X.apply(lambda x: tokenizer.encode(x, padding='max_length', truncation=True))
    X = X.apply(pd.Series)
    
    return X, y

# %%
if not LOAD_TENSORS:
    X_train, y_train = preprocess_inputs(df_train)
    X_val, y_val = preprocess_inputs(df_val)
    X_test, y_test = preprocess_inputs(df_test)
    
    X_train = torch.tensor(X_train.values).to(device)
    y_train = torch.tensor(y_train.values).long().to(device)
    X_val = torch.tensor(X_val.values).to(device)
    y_val = torch.tensor(y_val.values).long().to(device)
    X_test = torch.tensor(X_test.values).to(device)
    y_test = torch.tensor(y_test.values).long().to(device)
else:
    X_train = torch.load(fr'{c.get_path_iteration()}/X_train.pt').to(device)
    y_train = torch.load(fr'{c.get_path_iteration()}/y_train.pt').to(device)
    X_val = torch.load(fr'{c.get_path_iteration()}/X_val.pt').to(device)
    y_val = torch.load(fr'{c.get_path_iteration()}/y_val.pt').to(device)
    X_test = torch.load(fr'{c.get_path_iteration()}/X_test.pt').to(device)
    y_test = torch.load(fr'{c.get_path_iteration()}/y_test.pt').to(device)

# %% [markdown]
# # Model development
#
# Use word embeddings for `REPORT_1_NARRATIVE`.

# %%
tokenizer.vocab_size
# Out:
# 50265

# %%
class WordEmbeddingModel(nn.Module):
    def __init__(self, vocab_size, sequence_length, embedding_size, hidden_size, output_size):
        super(WordEmbeddingModel, self).__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        
        self.fcs = [
            nn.Linear(sequence_length * embedding_size, hidden_size),
            nn.Linear(hidden_size, hidden_size),
            nn.Linear(hidden_size, output_size),
        ]
        
        self.leaky_relu = nn.LeakyReLU()
    
    def forward(self, x):
        # print(f'{x.shape=}')
        embedded = self.embedding(x)
        # print(f'{embedded.shape=}')
        
        flattened = torch.flatten(embedded, 1)
        # print(f'{flattened.shape=}')
        
        out = flattened
        
        for fc in self.fcs:
            out = fc(out)
            out = self.leaky_relu(out)
            # print(f'{out.shape=}')
    
        return out

# %%
vocab_size = tokenizer.vocab_size
embedding_size = 2048
hidden_size = 32
output_size = 5
sequence_length = 512

learning_rate = 0.01
REG_PARAM = 0.02
num_epochs = 100
batch_size = 1024

model = WordEmbeddingModel(vocab_size, sequence_length, embedding_size, hidden_size, output_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=REG_PARAM)

# %%
# Create data loaders for train, validation, and test sets
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

test_dataset = torch.utils.data.TensorDataset(X_test, y_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for epoch in range(num_epochs):
    train_losses = []
    val_losses = []
    
    # Train
    model.train()
    for inputs, labels in train_loader:
        inputs.to(device)
        labels.to(device)
        outputs = model(inputs)

        loss = criterion(outputs, labels)
        train_losses.append(loss.item())
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs.to(device)
            labels.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, labels).item()
            val_losses.append(val_loss)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # Report metrics
    train_loss = np.mean(train_losses)
    val_loss = np.mean(val_losses)
    val_accuracy = 100.0 * correct / total
    print(f'epoch={epoch+1:02d} | train_loss={train_loss:.5f} | val_loss={val_loss:.5f} | val_acc={val_accuracy:.2f}%')

# %% [markdown]
# # Validate model

# %%
model.eval()
test_losses = []
correct = 0
total = 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs.to(device)
        labels.to(device)
        outputs = model(inputs)
        test_losses.append(criterion(outputs, labels).item())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Print test metrics
test_loss = np.mean(test_losses)
test_accuracy = 100.0 * correct / total
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Loss: 1.4459, Test Accuracy: 39.93%

# %% [markdown]
# # Saving to files

# %%
# Save the tensors
torch.save(X_train, fr'{c.get_path_iteration()}/X_train.pt')
torch.save(y_train, fr'{c.get_path_iteration()}/y_train.pt')
torch.save(X_val, fr'{c.get_path_iteration()}/X_val.pt')
torch.save(y_val, fr'{c.get_path_iteration()}/y_val.pt')
torch.save(X_test, fr'{c.get_path_iteration()}/X_test.pt')
torch.save(y_test, fr'{c.get_path_iteration()}/y_test.pt')
