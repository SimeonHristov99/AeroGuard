# %%
# ! pip install inflect
# ! pip install pycaret

# %% [markdown]
# # Inputs

# %%
import re
import textwrap

import inflect
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
stop_words = stopwords.words('english')

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import resample

from sklearn.svm import SVC
from sklearn.metrics import classification_report

# import pycaret.classification as pc
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Load data

# %%
filename = r'/kaggle/input/asrs-aeroguard/01_df_train_val_test.pkl'
df_dev = pd.read_pickle(filename)
df_dev
# Out:
#        ACN_NUM_ACN  TIME_DATE TIME_1_LOCAL_TIME_OF_DAY PLACE_LOCALE_REFERENCE  \
# 0          1574675     201808                0601-1200            SNA.Airport
# 1          1224894     201412                0601-1200            MSY.Airport
# 2          1134202     201312                1201-1800              ZZZ.ARTCC
# 3          1222074     201411                1201-1800            CWA.Airport
# 4          1733019     202003                1801-2400              ZDV.ARTCC
# ...            ...        ...                      ...                    ...
# 47718      1341108     201603                0601-1200            ZZZ.Airport
# 47719      1087474     201305                1201-1800            PHX.Airport
# 47720      1756601     202008                       NA                     NA
# 47721      1102938     201307                0601-1200            MEM.Airport
# 47722      1681426     201909                0001-0600            ZZZ.Airport
#
#       PLACE_1_STATE_REFERENCE  PLACE_2_RELATIVE_POSITION_ANGLE_RADIAL  \
# 0                          CA                                     NaN
# 1                          LA                                     NaN
# 2                          US                                     NaN
# 3                          WI                                     NaN
# 4                          CO                                     NaN
# ...                       ...                                     ...
# 47718                      US                                     NaN
# 47719                      AZ                                     NaN
# 47720                      NA                                     NaN
# 47721                      TN                                     NaN
# 47722                      US                                     NaN
#
#        PLACE_3_RELATIVE_POSITION_DISTANCE_NAUTICAL_MILES  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   20.0
# 4                                                    NaN
# ...                                                  ...
# 47718                                                NaN
# 47719                                                NaN
# 47720                                                NaN
# 47721                                                NaN
# 47722                                                NaN
#
#        PLACE_4_ALTITUDE_AGL_SINGLE_VALUE  PLACE_5_ALTITUDE_MSL_SINGLE_VALUE  \
# 0                                    NaN                             5000.0
# 1                                 1000.0                                NaN
# 2                                    NaN                             2600.0
# 3                                    NaN                             4000.0
# 4                                    NaN                            32000.0
# ...                                  ...                                ...
# 47718                                NaN                                NaN
# 47719                                NaN                             8000.0
# 47720                                0.0                                NaN
# 47721                                NaN                                NaN
# 47722                                0.0                                NaN
#
#       ENVIRONMENT_FLIGHT_CONDITIONS  ...  \
# 0                                NA  ...
# 1                               VMC  ...
# 2                               IMC  ...
# 3                                NA  ...
# 4                                NA  ...
# ...                             ...  ...
# 47718                           IMC  ...
# 47719                           VMC  ...
# 47720                            NA  ...
# 47721                           VMC  ...
# 47722                            NA  ...
#
#              ASSESSMENTS_CONTRIBUTING_FACTORS_SITUATIONS  \
# 0                                          Human Factors
# 1                                          Human Factors
# 2            Human Factors; Aircraft; Procedure; Weather
# 3                                               Aircraft
# 4                            Airspace Structure; Weather
# ...                                                  ...
# 47718                      Company Policy; Human Factors
# 47719                 Aircraft; Human Factors; Procedure
# 47720  Environment - Non Weather Related; Company Pol...
# 47721  Airspace Structure; Chart Or Publication; Proc...
# 47722  Incorrect / Not Installed / Unavailable Part; ...
#
#       ASSESSMENTS_1_PRIMARY_PROBLEM  \
# 0                     Human Factors
# 1                     Human Factors
# 2                          Aircraft
# 3                          Aircraft
# 4                           Weather
# ...                             ...
# 47718                 Human Factors
# 47719                     Ambiguous
# 47720                Company Policy
# 47721                 Human Factors
# 47722                     Procedure
#
#                                       REPORT_1_NARRATIVE REPORT_1_1_CALLBACK  \
# 0      SNA RNP-Z to Runway 20R. The FMC was properly ...                  NA
# 1      On base to final turn to runway 1 in MSY at ap...                  NA
# 2      I climbed to my filed altitude of 5;000 FT; an...                  NA
# 3      I had my pitot heat checked prior to winter an...                  NA
# 4      At 32000 ft. just north of PUB the aircraft ex...                  NA
# ...                                                  ...                 ...
# 47718  We did an originator out of ZZZ and had a main...                  NA
# 47719  PHX takeoff Runway 25R flaps 5. CLEARANCE: MAX...                  NA
# 47720  I was scheduled to complete the one day traini...                  NA
# 47721  We departed Runway 36C in MEM via the GOETZ TW...                  NA
# 47722  Walking to the aircraft; the inbound crew info...                  NA
#
#                                       REPORT_2_NARRATIVE REPORT_2_1_CALLBACK  \
# 0      We were cleared for the RNP RNAV Z 20R Approac...                  NA
# 1                                                     NA                  NA
# 2                                                     NA                  NA
# 3                                                     NA                  NA
# 4                                                     NA                  NA
# ...                                                  ...                 ...
# 47718  [Report narrative contained no additional info...                  NA
# 47719  There was an Airbus that departed before us an...                  NA
# 47720                                                 NA                  NA
# 47721                                                 NA                  NA
# 47722                                                 NA                  NA
#
#                                      REPORT_1_2_SYNOPSIS TRAIN_VAL_TEST_SPLIT  \
# 0      B737-700 flight crew reported failing to make ...                Train
# 1      Captain reports sighting of a drone at 1;000 f...                Train
# 2      SR22 pilot became disoriented on approach in I...                Train
# 3      BE58 pilot experiences pitot heat failure desc...                Train
# 4      B737 First Officer reported unexpected moderat...                Train
# ...                                                  ...                  ...
# 47718  CRJ-900 flight crew reported being dispatched ...                 Test
# 47719  CE750 flight crew departing PHX Runway 25R on ...                 Test
# 47720  Air carrier First Officer reported that re-qua...                 Test
# 47721  On initial climb out via the GOETZ RNAV SID fr...                 Test
# 47722  A319 Captain reported an incorrect MEL action ...                 Test
#
#       EVENT_RISK          EVENT_RISK_STR
# 0              2             Medium risk
# 1              0                Low risk
# 2              3    Moderately high risk
# 3              2             Medium risk
# 4              3    Moderately high risk
# ...          ...                     ...
# 47718          3    Moderately high risk
# 47719          3    Moderately high risk
# 47720          0                Low risk
# 47721          2             Medium risk
# 47722          1  Moderately medium risk
#
# [47723 rows x 114 columns]

# %%
# df_dev = df_dev.sample(frac=0.5).reset_index(drop=True)
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(df_dev['REPORT_1_2_SYNOPSIS'])
# tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
# tfidf_df['target'] = df_dev['EVENT_RISK']
# s1 = pc.setup(data=tfidf_df, target='target')
# best = pc.compare_models()

# %% [markdown]
# # Preprocessing

# %%
p = inflect.engine()


def remove_stopwords_and_punctuation(text):
    tokens = word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words and token not in string.punctuation]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

def convert_numbers_to_words(text):
    parts = re.findall(r'\d+|\D+', text)
    parts = [p.number_to_words(int(part)) if part.isdigit() else part for part in parts]
    text_num2word = ' '.join(parts)
    return text_num2word

def preprocess_inputs(df):
    df = df.copy()
    
    # Lowercase words
    df['REPORT_1_2_SYNOPSIS'] = df['REPORT_1_2_SYNOPSIS'].str.lower()
    
    # Make any numbers be their word equivalent
    df['REPORT_1_2_SYNOPSIS'] = df['REPORT_1_2_SYNOPSIS'].apply(convert_numbers_to_words)
    
    # Remove stopwords
    df['REPORT_1_2_SYNOPSIS'] = df['REPORT_1_2_SYNOPSIS'].apply(remove_stopwords_and_punctuation)
    
    return df

def resample_data(df, target_col):
    class_counts = df[target_col].value_counts()
    min_count = class_counts.min()
    
    # Resample the data for each class to match the minority class count
    resampled_dfs = []
    for label, count in class_counts.items():
        class_df = df[df[target_col] == label]
        resampled_df = resample(class_df, replace=True, n_samples=min_count, random_state=42)
        resampled_dfs.append(resampled_df)
    
    # Concatenate the resampled dataframes
    resampled_df = pd.concat(resampled_dfs)
    
    return resampled_df

def upsample_data(df, target_col):
    class_counts = df[target_col].value_counts()
    max_count = class_counts.max()

    # Upsample the data for each class to match the majority class count
    upsampled_dfs = []
    for label, count in class_counts.items():
        class_df = df[df[target_col] == label]
        upsampled_df = resample(class_df, replace=True, n_samples=max_count, random_state=42)
        upsampled_dfs.append(upsampled_df)

    # Concatenate the upsampled dataframes
    upsampled_df = pd.concat(upsampled_dfs)

    return upsampled_df

# %%
df = preprocess_inputs(df_dev)

df_resampled = resample_data(df, 'EVENT_RISK')
# df_upsampled = upsample_data(df, 'EVENT_RISK')

df
# Out:
#        ACN_NUM_ACN  TIME_DATE TIME_1_LOCAL_TIME_OF_DAY PLACE_LOCALE_REFERENCE  \
# 0          1574675     201808                0601-1200            SNA.Airport
# 1          1224894     201412                0601-1200            MSY.Airport
# 2          1134202     201312                1201-1800              ZZZ.ARTCC
# 3          1222074     201411                1201-1800            CWA.Airport
# 4          1733019     202003                1801-2400              ZDV.ARTCC
# ...            ...        ...                      ...                    ...
# 47718      1341108     201603                0601-1200            ZZZ.Airport
# 47719      1087474     201305                1201-1800            PHX.Airport
# 47720      1756601     202008                       NA                     NA
# 47721      1102938     201307                0601-1200            MEM.Airport
# 47722      1681426     201909                0001-0600            ZZZ.Airport
#
#       PLACE_1_STATE_REFERENCE  PLACE_2_RELATIVE_POSITION_ANGLE_RADIAL  \
# 0                          CA                                     NaN
# 1                          LA                                     NaN
# 2                          US                                     NaN
# 3                          WI                                     NaN
# 4                          CO                                     NaN
# ...                       ...                                     ...
# 47718                      US                                     NaN
# 47719                      AZ                                     NaN
# 47720                      NA                                     NaN
# 47721                      TN                                     NaN
# 47722                      US                                     NaN
#
#        PLACE_3_RELATIVE_POSITION_DISTANCE_NAUTICAL_MILES  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   20.0
# 4                                                    NaN
# ...                                                  ...
# 47718                                                NaN
# 47719                                                NaN
# 47720                                                NaN
# 47721                                                NaN
# 47722                                                NaN
#
#        PLACE_4_ALTITUDE_AGL_SINGLE_VALUE  PLACE_5_ALTITUDE_MSL_SINGLE_VALUE  \
# 0                                    NaN                             5000.0
# 1                                 1000.0                                NaN
# 2                                    NaN                             2600.0
# 3                                    NaN                             4000.0
# 4                                    NaN                            32000.0
# ...                                  ...                                ...
# 47718                                NaN                                NaN
# 47719                                NaN                             8000.0
# 47720                                0.0                                NaN
# 47721                                NaN                                NaN
# 47722                                0.0                                NaN
#
#       ENVIRONMENT_FLIGHT_CONDITIONS  ...  \
# 0                                NA  ...
# 1                               VMC  ...
# 2                               IMC  ...
# 3                                NA  ...
# 4                                NA  ...
# ...                             ...  ...
# 47718                           IMC  ...
# 47719                           VMC  ...
# 47720                            NA  ...
# 47721                           VMC  ...
# 47722                            NA  ...
#
#              ASSESSMENTS_CONTRIBUTING_FACTORS_SITUATIONS  \
# 0                                          Human Factors
# 1                                          Human Factors
# 2            Human Factors; Aircraft; Procedure; Weather
# 3                                               Aircraft
# 4                            Airspace Structure; Weather
# ...                                                  ...
# 47718                      Company Policy; Human Factors
# 47719                 Aircraft; Human Factors; Procedure
# 47720  Environment - Non Weather Related; Company Pol...
# 47721  Airspace Structure; Chart Or Publication; Proc...
# 47722  Incorrect / Not Installed / Unavailable Part; ...
#
#       ASSESSMENTS_1_PRIMARY_PROBLEM  \
# 0                     Human Factors
# 1                     Human Factors
# 2                          Aircraft
# 3                          Aircraft
# 4                           Weather
# ...                             ...
# 47718                 Human Factors
# 47719                     Ambiguous
# 47720                Company Policy
# 47721                 Human Factors
# 47722                     Procedure
#
#                                       REPORT_1_NARRATIVE REPORT_1_1_CALLBACK  \
# 0      SNA RNP-Z to Runway 20R. The FMC was properly ...                  NA
# 1      On base to final turn to runway 1 in MSY at ap...                  NA
# 2      I climbed to my filed altitude of 5;000 FT; an...                  NA
# 3      I had my pitot heat checked prior to winter an...                  NA
# 4      At 32000 ft. just north of PUB the aircraft ex...                  NA
# ...                                                  ...                 ...
# 47718  We did an originator out of ZZZ and had a main...                  NA
# 47719  PHX takeoff Runway 25R flaps 5. CLEARANCE: MAX...                  NA
# 47720  I was scheduled to complete the one day traini...                  NA
# 47721  We departed Runway 36C in MEM via the GOETZ TW...                  NA
# 47722  Walking to the aircraft; the inbound crew info...                  NA
#
#                                       REPORT_2_NARRATIVE REPORT_2_1_CALLBACK  \
# 0      We were cleared for the RNP RNAV Z 20R Approac...                  NA
# 1                                                     NA                  NA
# 2                                                     NA                  NA
# 3                                                     NA                  NA
# 4                                                     NA                  NA
# ...                                                  ...                 ...
# 47718  [Report narrative contained no additional info...                  NA
# 47719  There was an Airbus that departed before us an...                  NA
# 47720                                                 NA                  NA
# 47721                                                 NA                  NA
# 47722                                                 NA                  NA
#
#                                      REPORT_1_2_SYNOPSIS TRAIN_VAL_TEST_SPLIT  \
# 0      b seven hundred thirty-seven seven hundred fli...                Train
# 1      captain reports sighting drone one zero feet a...                Train
# 2      sr twenty-two pilot became disoriented approac...                Train
# 3      fifty-eight pilot experiences pitot heat failu...                Train
# 4      b seven hundred thirty-seven first officer rep...                Train
# ...                                                  ...                  ...
# 47718  crj- nine hundred flight crew reported dispatc...                 Test
# 47719  ce seven hundred fifty flight crew departing p...                 Test
# 47720  air carrier first officer reported re-qualific...                 Test
# 47721  initial climb via goetz rnav sid mem flight cr...                 Test
# 47722  three hundred nineteen captain reported incorr...                 Test
#
#       EVENT_RISK          EVENT_RISK_STR
# 0              2             Medium risk
# 1              0                Low risk
# 2              3    Moderately high risk
# 3              2             Medium risk
# 4              3    Moderately high risk
# ...          ...                     ...
# 47718          3    Moderately high risk
# 47719          3    Moderately high risk
# 47720          0                Low risk
# 47721          2             Medium risk
# 47722          1  Moderately medium risk
#
# [47723 rows x 114 columns]

# %%
df_resampled
# Out:
#        ACN_NUM_ACN  TIME_DATE TIME_1_LOCAL_TIME_OF_DAY PLACE_LOCALE_REFERENCE  \
# 45523      1677539     201908                1201-1800            ZZZ.Airport
# 2436       1602786     201812                1201-1800            SJC.Airport
# 15575      1021250     201207                0601-1200             ZZZZ.ARTCC
# 34424      1829993     202108                0601-1200            MHT.Airport
# 32550      1502244     201712                1801-2400            SEA.Airport
# ...            ...        ...                      ...                    ...
# 32744      1756021     201909                0001-0600                     NA
# 2510       1641805     201904                1201-1800            ARR.Airport
# 7830       1744809     202006                0601-1200            ZZZ.Airport
# 22085      1655307     201906                0601-1200            ZZZ.Airport
# 31314      1578867     201809                1201-1800            ZZZ.Airport
#
#       PLACE_1_STATE_REFERENCE  PLACE_2_RELATIVE_POSITION_ANGLE_RADIAL  \
# 45523                      US                                     NaN
# 2436                       CA                                     NaN
# 15575                      FO                                     NaN
# 34424                      NH                                    90.0
# 32550                      WA                                     NaN
# ...                       ...                                     ...
# 32744                      NA                                     NaN
# 2510                       IL                                     NaN
# 7830                       US                                     NaN
# 22085                      US                                     NaN
# 31314                      US                                     NaN
#
#        PLACE_3_RELATIVE_POSITION_DISTANCE_NAUTICAL_MILES  \
# 45523                                                NaN
# 2436                                                 NaN
# 15575                                                NaN
# 34424                                               35.0
# 32550                                                NaN
# ...                                                  ...
# 32744                                                NaN
# 2510                                                 NaN
# 7830                                                 1.0
# 22085                                                NaN
# 31314                                                NaN
#
#        PLACE_4_ALTITUDE_AGL_SINGLE_VALUE  PLACE_5_ALTITUDE_MSL_SINGLE_VALUE  \
# 45523                                NaN                             2300.0
# 2436                                 NaN                             8000.0
# 15575                                NaN                            33000.0
# 34424                                NaN                            12000.0
# 32550                              800.0                                NaN
# ...                                  ...                                ...
# 32744                                0.0                                NaN
# 2510                                 NaN                             1700.0
# 7830                                25.0                                NaN
# 22085                             1000.0                                NaN
# 31314                                0.0                                NaN
#
#       ENVIRONMENT_FLIGHT_CONDITIONS  ...  \
# 45523                           VMC  ...
# 2436                            VMC  ...
# 15575                           VMC  ...
# 34424                            NA  ...
# 32550                           VMC  ...
# ...                             ...  ...
# 32744                           VMC  ...
# 2510                            VMC  ...
# 7830                            VMC  ...
# 22085                      Marginal  ...
# 31314                            NA  ...
#
#              ASSESSMENTS_CONTRIBUTING_FACTORS_SITUATIONS  \
# 45523                                           Aircraft
# 2436                     Chart Or Publication; Procedure
# 15575                                           Aircraft
# 34424                                 Procedure; Weather
# 32550                      Airspace Structure; Procedure
# ...                                                  ...
# 32744  Procedure; Logbook Entry; Human Factors; Aircr...
# 2510                              Airport; Human Factors
# 7830                                            Aircraft
# 22085                                           Aircraft
# 31314                  Environment - Non Weather Related
#
#            ASSESSMENTS_1_PRIMARY_PROBLEM  \
# 45523                           Aircraft
# 2436                Chart Or Publication
# 15575                           Aircraft
# 34424                          Procedure
# 32550                          Procedure
# ...                                  ...
# 32744                      Logbook Entry
# 2510                             Airport
# 7830                            Aircraft
# 22085                           Aircraft
# 31314  Environment - Non Weather Related
#
#                                       REPORT_1_NARRATIVE REPORT_1_1_CALLBACK  \
# 45523  On visual approach Runway XR ZZZ approximately...                  NA
# 2436   I inputted the SJC2 Departure which has a tran...                  NA
# 15575  While enroute at 33;000 FT; Engine EICAS indic...                  NA
# 34424  We had spoken with Dispatch two hours before t...                  NA
# 32550  We had TCAS/RA on short final to runway 34L at...                  NA
# ...                                                  ...                 ...
# 32744  Crew was dispatched for [a flight]. An Eng Chi...                  NA
# 2510   Aircraft X was performing pattern work in left...                  NA
# 7830   This flight was a cross country instructional ...                  NA
# 22085  After takeoff; First Officer asked me if I sme...                  NA
# 31314  Aircraft X was pulled out of service for a rep...                  NA
#
#                                       REPORT_2_NARRATIVE REPORT_2_1_CALLBACK  \
# 45523  On final to [Runway] XR at ZZZ we attempted to...                  NA
# 2436   I inputted the SJC2 Departure which has a tran...                  NA
# 15575                                                 NA                  NA
# 34424                                                 NA                  NA
# 32550                                                 NA                  NA
# ...                                                  ...                 ...
# 32744                                                 NA                  NA
# 2510                                                  NA                  NA
# 7830                                                  NA                  NA
# 22085  On initial climbout; detected a strong odor th...                  NA
# 31314                                                 NA                  NA
#
#                                      REPORT_1_2_SYNOPSIS TRAIN_VAL_TEST_SPLIT  \
# 45523  three hundred twenty flight crew reported land...                 Test
# 2436   embraer aircraft flight crew reported confusio...                Train
# 15575  b seven hundred forty-seven four hundred capta...                Train
# 34424  air carrier captain reported filing reroute av...                Train
# 32550  air carrier captain reported ra final approach...                Train
# ...                                                  ...                  ...
# 32744  helicopter pilot reported misgivings due suspe...                Train
# 2510   aurora tower controller reported airport probl...                Train
# 7830   c one hundred seventy-two instructor pilot rep...                Train
# 22085  three hundred nineteen flight crew reported pr...                Train
# 31314  maintenance reported supervisor improperly han...                Train
#
#       EVENT_RISK          EVENT_RISK_STR
# 45523          2             Medium risk
# 2436           2             Medium risk
# 15575          2             Medium risk
# 34424          2             Medium risk
# 32550          2             Medium risk
# ...          ...                     ...
# 32744          1  Moderately medium risk
# 2510           1  Moderately medium risk
# 7830           1  Moderately medium risk
# 22085          1  Moderately medium risk
# 31314          1  Moderately medium risk
#
# [28775 rows x 114 columns]

# %% [markdown]
# # Modelling

# %%
df = df_resampled.sample(frac=0.2).reset_index(drop=True)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()

train_tfidf = vectorizer.fit_transform(train_df['REPORT_1_2_SYNOPSIS'])

val_tfidf = vectorizer.transform(val_df['REPORT_1_2_SYNOPSIS'])
test_tfidf = vectorizer.transform(test_df['REPORT_1_2_SYNOPSIS'])

svm = SVC()

svm.fit(train_tfidf, train_df['EVENT_RISK'])

val_predictions = svm.predict(val_tfidf)

f1 = f1_score(val_df['EVENT_RISK'], val_predictions, average='weighted')
print(f'{f1=}')
# Out:
# f1=0.5407929425590797

# %%
df = df_resampled.sample(frac=0.4).reset_index(drop=True)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()

train_tfidf = vectorizer.fit_transform(train_df['REPORT_1_2_SYNOPSIS'])

val_tfidf = vectorizer.transform(val_df['REPORT_1_2_SYNOPSIS'])
test_tfidf = vectorizer.transform(test_df['REPORT_1_2_SYNOPSIS'])

svm = SVC()

svm.fit(train_tfidf, train_df['EVENT_RISK'])

val_predictions = svm.predict(val_tfidf)

f1 = f1_score(val_df['EVENT_RISK'], val_predictions, average='weighted')
print(f'{f1=}')
# Out:
# f1=0.5933471361497498

# %%
df = df_resampled.sample(frac=0.6).reset_index(drop=True)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()

train_tfidf = vectorizer.fit_transform(train_df['REPORT_1_2_SYNOPSIS'])

val_tfidf = vectorizer.transform(val_df['REPORT_1_2_SYNOPSIS'])
test_tfidf = vectorizer.transform(test_df['REPORT_1_2_SYNOPSIS'])

svm = SVC()

svm.fit(train_tfidf, train_df['EVENT_RISK'])

val_predictions = svm.predict(val_tfidf)

f1 = f1_score(val_df['EVENT_RISK'], val_predictions, average='weighted')
print(f'{f1=}')
# Out:
# f1=0.6176473922072306

# %%
df = df_resampled.sample(frac=0.8).reset_index(drop=True)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()

train_tfidf = vectorizer.fit_transform(train_df['REPORT_1_2_SYNOPSIS'])

val_tfidf = vectorizer.transform(val_df['REPORT_1_2_SYNOPSIS'])
test_tfidf = vectorizer.transform(test_df['REPORT_1_2_SYNOPSIS'])

svm = SVC()

svm.fit(train_tfidf, train_df['EVENT_RISK'])

val_predictions = svm.predict(val_tfidf)

f1 = f1_score(val_df['EVENT_RISK'], val_predictions, average='weighted')
print(f'{f1=}')
# Out:
# f1=0.6563595338400524

# %%
df = df_resampled.copy()

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()

train_tfidf = vectorizer.fit_transform(train_df['REPORT_1_2_SYNOPSIS'])

val_tfidf = vectorizer.transform(val_df['REPORT_1_2_SYNOPSIS'])
test_tfidf = vectorizer.transform(test_df['REPORT_1_2_SYNOPSIS'])

svm = SVC()

svm.fit(train_tfidf, train_df['EVENT_RISK'])

val_predictions = svm.predict(val_tfidf)

f1 = f1_score(val_df['EVENT_RISK'], val_predictions, average='weighted')
print(f'{f1=}')
# Out:
# f1=0.6699638306909764
